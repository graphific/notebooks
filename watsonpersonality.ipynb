# %% [markdown]
# #A.I Astrology
# ###Predicting Social Characteristics of Famous People using Natural Language Processing

# %% [markdown]
# Similarity scores for the persons in [Samim's](https://twitter.com/samim) A.I Astrology [Medium Post](https://medium.com/@samim/a-i-astrology-804cbec95968)
#
# <img src="https://cdn-images-1.medium.com/max/1566/1*ltPwCgpPYwxQVbIvMbPNtw.jpeg" style="display:inline; width: 30%" />
#
# fast code hacked together by [Roelof Pieters](https://twitter.com/graphific)

# %%
#fastest, just html, instead of post request to: https://watson-pi-demo.mybluemix.net/
kinghtml = """<div class="col-lg-5 col-md-12 col-xs-12"><h3>Data Behind Your Personality</h3><div style="" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>91%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>76%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>23%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>89%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>88%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>49%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>91%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>56%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>17%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>74%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>53%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>4%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>24%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>13%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>59%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>13%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>39%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>85%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>85%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>19%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>37%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>60%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>19%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>11%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>8%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>97%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>39%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>20%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>25%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>61%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>34%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>72%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>42%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>48%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>52%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>44%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>92%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div></div></div>"""
stalinhtml = """<div style="display: block;" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>91%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>47%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>26%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>93%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>55%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>67%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>18%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>70%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>10%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>37%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>68%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>4%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>64%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>31%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>83%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>29%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>54%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>59%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>28%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>10%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>88%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>20%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>21%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>37%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>12%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>12%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>85%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>75%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>81%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>84%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>75%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>90%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>74%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>38%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>93%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>91%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>93%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div></div>"""
jacksonhtml = """<div style="display: block;" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>46%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>41%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>92%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>81%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>62%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>36%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>74%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>47%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>70%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>47%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>31%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>77%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>91%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>86%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>89%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>15%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>61%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>90%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>35%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>30%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>43%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>48%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>32%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>30%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>26%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>8%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>11%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>6%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>22%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>4%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>41%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>54%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>31%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>18%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>27%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>45%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>30%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>32%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>25%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>9%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>6%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>97%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>29%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div></div>"""
teresahtml = """<div style="display: block;" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>8%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>17%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>94%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>94%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>10%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>23%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>32%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>47%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>9%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>63%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>56%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>96%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>50%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>72%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>96%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>83%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>63%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>77%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>73%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>51%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>20%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>68%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>9%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>78%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>12%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>58%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>86%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>48%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>26%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>6%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>14%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>77%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>3%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div></div>"""
bushhtml = """<div style="display: block;" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>83%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>80%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>89%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>60%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>64%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>80%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>54%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>50%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>36%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>22%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>8%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>9%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>53%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>78%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>86%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>8%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>82%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>47%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>40%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>92%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>76%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>68%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>85%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>28%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>20%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>18%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>20%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>51%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>58%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>68%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>51%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>23%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>44%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>96%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>70%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>88%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>86%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>87%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>81%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>71%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>84%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>94%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>94%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div></div>"""
gandhihtml = """<div style="display: block;" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>68%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>40%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>54%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>71%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>76%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>69%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>13%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>9%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>31%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>6%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>40%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>58%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>53%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>1%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>82%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>34%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>54%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>21%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>18%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>28%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>12%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>23%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>3%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>10%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>91%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>5%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>76%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>83%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>59%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>72%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>55%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>32%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>56%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>94%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>80%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>40%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>54%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>97%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>38%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>65%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>86%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>77%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>63%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>90%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>7%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>26%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>97%</span></div></div></div></div>"""
elizabethhtml = """<div style="display: block;" class="col555px well traits"><div id="header-template"><div class="row theader"><div class="col-lg-7 col-xs-7"><span>Name</span></div><div class="col-lg-5 col-xs-5 text-right"><span>Value</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Big 5 </span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>53%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Adventurousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>65%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Artistic interests</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>96%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotionality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>84%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Imagination</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>21%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Intellect</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>44%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Authority-challenging</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>6%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conscientiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>26%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Achievement striving</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>11%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cautiousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>31%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Dutifulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>19%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Orderliness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>17%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-discipline</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>43%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-efficacy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>70%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Extraversion</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Activity level</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Assertiveness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cheerfulness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>90%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement-seeking</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>32%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Outgoing</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Gregariousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Agreeableness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Altruism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>94%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Cooperation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>66%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Modesty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>67%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Uncompromising</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>81%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Sympathy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Trust</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>58%</span></div></div></div><div class="row model_title" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Emotional range</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>46%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Fiery</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>52%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Prone to worry</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>71%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Melancholy</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>60%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Immoderation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>28%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-consciousness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>0%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Susceptible to stress</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>42%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Needs</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Challenge</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>95%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Closeness</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>97%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Curiosity</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>68%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Excitement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>89%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Harmony</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Ideal</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>81%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Liberty</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>92%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Love</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>100%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Practicality</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>97%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-expression</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>47%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Stability</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>89%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Structure</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>89%</span></div></div></div><div class="row model_title model_name" id="model-template"><div class="row"><div class="col-lg-12 col-xs-12 text-center"><span>Values</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Conservation</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>6%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Openness to change</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>74%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Hedonism</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>4%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-enhancement</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>2%</span></div></div></div><div class="row model_trait" id="trait-template"><div class="row"><div class="tname col-lg-7 col-xs-7"><span>Self-transcendence</span></div><div class="tvalue col-lg-5 col-xs-5 text-right"><span>98%</span></div></div></div></div>"""

# %%
ppl = [{'Michael Jackson':[jacksonhtml,[]]},
       {'Martin Luther King, Jr.':[kinghtml,[]]},
       {'Joseph Stalin':[stalinhtml,[]]},
       {'Mother Teresa':[teresahtml,[]]},
       {'George W. Bush':[bushhtml,[]]},
       {'Mahatma Gandhi':[gandhihtml,[]]},
       {'Queen Elizabeth II':[elizabethhtml,[]]},
      ]

# %%
from BeautifulSoup import BeautifulSoup
for vals in ppl:
    parsed_html = BeautifulSoup(vals.values()[0][0]) #parse html
    for div in parsed_html.findAll('div', attrs={'id':'trait-template'}):
        vals.values()[0][1].append(int(div.findAll('span')[1].text[:-1])) #append score

# %%
for vals in ppl:
    print vals.keys()[0] #label
    print vals.values()[0][1] #Personality Data
# Out:
# Michael Jackson
# [46, 41, 92, 81, 62, 36, 5, 74, 47, 70, 47, 31, 77, 87, 91, 5, 86, 89, 15, 87, 61, 90, 87, 35, 30, 43, 48, 32, 14, 30, 26, 8, 11, 6, 22, 4, 41, 54, 31, 18, 27, 45, 30, 32, 5, 25, 9, 6, 97, 29, 0, 100]
# Martin Luther King, Jr.
# [95, 91, 76, 23, 89, 95, 88, 87, 49, 91, 56, 17, 74, 95, 53, 4, 24, 13, 5, 59, 13, 39, 85, 85, 19, 37, 100, 60, 14, 19, 11, 8, 1, 1, 2, 97, 39, 20, 25, 61, 14, 34, 72, 42, 48, 52, 44, 2, 92, 14, 5, 100]
# Joseph Stalin
# [91, 87, 47, 26, 87, 93, 55, 67, 18, 70, 10, 14, 37, 87, 68, 4, 64, 31, 5, 83, 29, 54, 59, 28, 5, 10, 88, 20, 21, 37, 12, 12, 5, 0, 1, 98, 95, 85, 75, 81, 84, 75, 90, 74, 38, 93, 91, 2, 93, 2, 2, 100]
# Mother Teresa
# [8, 17, 94, 94, 1, 14, 0, 10, 2, 23, 32, 47, 9, 63, 100, 1, 98, 100, 56, 100, 100, 100, 96, 50, 72, 96, 100, 83, 63, 77, 73, 51, 20, 0, 68, 9, 78, 12, 58, 98, 1, 86, 100, 100, 48, 26, 6, 14, 77, 3, 0, 100]
# George W. Bush
# ...

# %%
from scipy import spatial
import itertools
for x in itertools.permutations([x for x in xrange(0,len(ppl))],2):
    if x[0] < x[1]:
        print "similarity",
        print ppl[x[0]].keys()[0],
        print "with",
        print ppl[x[1]].keys()[0],":",
        print 1 - spatial.distance.cosine(ppl[x[0]].values()[0][1], ppl[x[1]].values()[0][1])
# Out:
# similarity Michael Jackson with Martin Luther King, Jr. : 0.807377600787
# similarity Michael Jackson with Joseph Stalin : 0.792501179666
# similarity Michael Jackson with Mother Teresa : 0.824887541472
# similarity Michael Jackson with George W. Bush : 0.822637874714
# similarity Michael Jackson with Mahatma Gandhi : 0.666173273629
# similarity Michael Jackson with Queen Elizabeth II : 0.843247588504
# similarity Martin Luther King, Jr. with Joseph Stalin : 0.892545881081
# similarity Martin Luther King, Jr. with Mother Teresa : 0.658072773501
# similarity Martin Luther King, Jr. with George W. Bush : 0.846917089808
# similarity Martin Luther King, Jr. with Mahatma Gandhi : 0.746512085792
# similarity Martin Luther King, Jr. with Queen Elizabeth II : 0.778661677153
# similarity Joseph Stalin with Mother Teresa : 0.696517288615
# similarity Joseph Stalin with George W. Bush : 0.949387350734
# similarity Joseph Stalin with Mahatma Gandhi : 0.863837551424
# ...

# %%
allres = []
import itertools
lastx = -1
for x in itertools.permutations([x for x in xrange(0,len(ppl))],2):
    #print x[0],x[1]
    if lastx != x[0]:
        print "---"
        lastx = x[0]
        print "similarity",
        print ppl[x[0]].keys()[0]
        print "---"
    if True: # x[0] < x[1]:
        print "with",
        print ppl[x[1]].keys()[0],":",
        score = 1 - spatial.distance.cosine(ppl[x[0]].values()[0][1], ppl[x[1]].values()[0][1])
        print score
    if x[0] < x[1]:
        allres.append([score,str(ppl[x[0]].keys()[0])+" & "+str(ppl[x[1]].keys()[0])])
# Out:
# ---
# similarity Michael Jackson
# ---
# with Martin Luther King, Jr. : 0.807377600787
# with Joseph Stalin : 0.792501179666
# with Mother Teresa : 0.824887541472
# with George W. Bush : 0.822637874714
# with Mahatma Gandhi : 0.666173273629
# with Queen Elizabeth II : 0.843247588504
# ---
# similarity Martin Luther King, Jr.
# ---
# with Michael Jackson : 0.807377600787
# with Joseph Stalin : 0.892545881081
# with Mother Teresa : 0.658072773501
# with George W. Bush : 0.846917089808
# with Mahatma Gandhi : 0.746512085792
# with Queen Elizabeth II : 0.778661677153
# ---
# similarity Joseph Stalin
# ---
# with Michael Jackson : 0.792501179666
# with Martin Luther King, Jr. : 0.892545881081
# with Mother Teresa : 0.696517288615
# with George W. Bush : 0.949387350734
# with Mahatma Gandhi : 0.863837551424
# with Queen Elizabeth II : 0.878675470156
# ---
# similarity Mother Teresa
# ---
# with Michael Jackson : 0.824887541472
# with Martin Luther King, Jr. : 0.658072773501
# ...

# %%
sorted(allres,reverse=True)
# Out:
# [[0.94942288365034311, 'George W. Bush & Queen Elizabeth II'],
#  [0.9493873507343713, 'Joseph Stalin & George W. Bush'],
#  [0.91523458083344456, 'Mother Teresa & Queen Elizabeth II'],
#  [0.892545881081097, 'Martin Luther King, Jr. & Joseph Stalin'],
#  [0.88445803693395175, 'George W. Bush & Mahatma Gandhi'],
#  [0.87867547015608727, 'Joseph Stalin & Queen Elizabeth II'],
#  [0.86383755142426899, 'Joseph Stalin & Mahatma Gandhi'],
#  [0.84691708980805991, 'Martin Luther King, Jr. & George W. Bush'],
#  [0.84324758850382342, 'Michael Jackson & Queen Elizabeth II'],
#  [0.83321318339328831, 'Mahatma Gandhi & Queen Elizabeth II'],
#  [0.82488754147154886, 'Michael Jackson & Mother Teresa'],
#  [0.82263787471377381, 'Michael Jackson & George W. Bush'],
#  [0.81601923568675849, 'Mother Teresa & George W. Bush'],
#  [0.80737760078726017, 'Michael Jackson & Martin Luther King, Jr.'],
#  [0.79250117966636857, 'Michael Jackson & Joseph Stalin'],
# ...

# %% [markdown]
# Make your own conclusions but Bush and Queen Elizabeth, as well as Bush and Stalin as the top 2 most similar "Personalities"...
#
# Then again, there's a great level of arbitrariness to these sorts of services, as with Martn Luther King and Mother Teresa being the "least" similar.
